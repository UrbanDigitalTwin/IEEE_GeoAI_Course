# %% [markdown]
# # Week 10: Final Project Template
#
# ## Overview
# This notebook serves as the **final project template** for the course. It is designed to help students organize a complete GeoAI workflow in a clear, reproducible, and presentation-ready format.
#
# By Week 10, students have already seen:
# - disaster data sources
# - machine learning and computer vision fundamentals
# - surface water detection
# - vehicle-based urban flood detection
# - flood-depth estimation pipelines
# - evaluation and error analysis
# - decision support logic
# - urban digital twin integration
#
# The final project asks students to **select one GeoAI disaster-management problem**, structure the workflow, generate outputs, and explain the practical value of the results.
#
# ## Learning Objectives
# - Organize a complete GeoAI workflow in notebook form
# - Define a problem, data source, method, and output clearly
# - Present results using code, tables, plots, and short interpretation
# - Reflect on limitations and future improvements
# - Build a portfolio-style artifact suitable for GitHub
#
# ## Expected Outcome
# By the end of this notebook, you should have a complete mini-project that demonstrates your understanding of GeoAI workflows for disaster management.

# %% [markdown]
# ## How to Use This Notebook
#
# This notebook is a **template**, not a fixed solution.
#
# Students may adapt it for one of several project directions, such as:
# - surface water or flood extent mapping
# - vehicle-based urban flood severity analysis
# - disaster-response decision support
# - digital twin integration for hazard monitoring
# - another disaster-management GeoAI use case approved by the instructor
#
# You can:
# - keep the sections as they are
# - replace placeholder text with your own content
# - add more plots, tables, or code cells
# - remove sections that are not relevant to your chosen project

# %% [markdown]
# ## Suggested Project Directions
#
# ### Option 1: Surface Water Detection
# Use segmentation concepts to identify water extent from geospatial imagery.
#
# ### Option 2: Urban Flood Severity Around Vehicles
# Use object detection and crop-based reasoning to assess flood severity in street-level scenes.
#
# ### Option 3: Decision-Support Workflow
# Convert flood model outputs into action categories, review flags, and priority rankings.
#
# ### Option 4: Urban Digital Twin Integration
# Place AI-derived flood outputs into a spatial and operational city context.
#
# ### Option 5: Your Own GeoAI Disaster Topic
# You may propose a different topic if it is clearly connected to disaster management and GeoAI.

# %%
# Week 10 setup: imports and environment check

import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Python version:", sys.version.split()[0])
print("Working directory:", os.getcwd())
# Out:
# Python version: 3.12.12
# Working directory: /content

# %%
# Create output folder for the final project

BASE_DIR = Path.cwd()
OUTPUT_DIR = BASE_DIR / "outputs" / "week10_final_project"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Output directory ready:", OUTPUT_DIR)
# Out:
# Output directory ready: /content/outputs/week10_final_project

# %% [markdown]
# # 1. Project Title and Team / Student Information
#
# Replace the text below with your own project information.

# %% [markdown]
# ## Project Title
# **[Enter your project title here]**
#
# ## Student Name
# [Enter your name here]
#
# ## Course
# GeoAI for Disaster Management
#
# ## Date
# [Enter submission date]
#
# ## Project Direction
# [Example: Urban Flood Severity Around Vehicles]

# %% [markdown]
# # 2. Problem Statement
#
# Describe the disaster-management problem you are addressing.
#
# Useful prompts:
# - What is the problem?
# - Why does it matter?
# - Who would benefit from this workflow?
# - What kind of decision or insight should the model support?

# %% [markdown]
# ## Problem Statement
# [Write 1–3 short paragraphs here.]
#
# Example ideas:
# - Detecting flood extent quickly from geospatial imagery
# - Estimating urban flood severity around vehicles
# - Prioritizing locations for emergency response
# - Integrating flood intelligence into a digital twin environment

# %% [markdown]
# # 3. Data and Inputs
#
# Explain the data you are using.
#
# Useful prompts:
# - What type of data is it?
# - Where did it come from?
# - Is it imagery, tabular data, geospatial data, or synthetic data?
# - What are the key variables or labels?
# - Why is this data suitable for the problem?

# %% [markdown]
# ## Data Description
# [Describe your dataset here.]
#
# Suggested details:
# - data source
# - image type or sensor type
# - spatial or temporal coverage
# - labels or annotations
# - important assumptions

# %% [markdown]
# # 4. Workflow Overview
#
# Describe the overall process from input data to final output.

# %%
# Optional: use this table to summarize your workflow

workflow_table = pd.DataFrame({
    "Step": [
        "Input data",
        "Preprocessing",
        "Modeling / analysis",
        "Evaluation",
        "Decision-support output"
    ],
    "Description": [
        "",
        "",
        "",
        "",
        ""
    ]
})

workflow_table
# Out:
#                       Step Description
# 0               Input data
# 1            Preprocessing
# 2      Modeling / analysis
# 3               Evaluation
# 4  Decision-support output

# %% [markdown]
# ## Workflow Description
# [Explain the workflow in paragraph form here.]
#
# Example:
# 1. Load the input data
# 2. Prepare the data for analysis
# 3. Run the model or logic
# 4. Evaluate the outputs
# 5. Summarize operational insights

# %% [markdown]
# # 5. Imports and Custom Setup
#
# Add the libraries and helper functions needed for your project below.

# %%
# Add project-specific imports here

# Example:
# import cv2
# import geopandas as gpd
# from pathlib import Path

# %% [markdown]
# # 6. Load Data
#
# Use the cells below to load your project data.

# %%
# Load your data here

# Example for CSV:
# df = pd.read_csv("your_data.csv")
# df.head()

# Example for image workflow:
# image_path = "example.jpg"
# image = plt.imread(image_path)
# plt.imshow(image)
# plt.axis("off")

# %% [markdown]
# ## Initial Data Inspection
# Use this section to show:
# - sample rows
# - sample images
# - summary statistics
# - missing values
# - label distribution

# %%
# Add initial inspection code here

# Example:
# df.info()
# df.describe()

# %% [markdown]
# # 7. Preprocessing
#
# Explain how you prepared the data.
#
# Examples:
# - cleaning missing values
# - image resizing
# - tiling geospatial scenes
# - normalization
# - feature creation
# - crop generation

# %% [markdown]
# ## Preprocessing Notes
# [Describe your preprocessing approach here.]

# %%
# Add preprocessing code here

# %% [markdown]
# # 8. Modeling or Analysis
#
# This is the core of your project.
#
# Depending on your topic, this may include:
# - segmentation
# - classification
# - object detection
# - scoring logic
# - geospatial overlay
# - temporal trend analysis
# - decision-support rule logic

# %% [markdown]
# ## Method / Model Description
# [Describe your approach here.]
#
# Useful prompts:
# - What method did you use?
# - Why was it selected?
# - What are the main parameters or assumptions?
# - Is it a learned model, a rule-based system, or a hybrid workflow?

# %%
# Add your main model or analysis code here

# %% [markdown]
# # 9. Results and Visualization
#
# Present your main outputs clearly.
#
# Possible outputs:
# - prediction tables
# - annotated images
# - segmentation masks
# - confusion matrices
# - severity summaries
# - maps
# - decision-support tables

# %%
# Add your main result visualizations here

# %% [markdown]
# ## Result Interpretation
# [Explain the results here.]
#
# Useful prompts:
# - What worked well?
# - What patterns do you observe?
# - What decisions could this output support?
# - Are the results practically meaningful?

# %% [markdown]
# # 10. Evaluation
#
# Even if your project is simple, include some form of evaluation.
#
# Examples:
# - accuracy or IoU
# - qualitative review
# - confusion matrix
# - threshold comparison
# - error analysis
# - sanity-check interpretation

# %% [markdown]
# ## Evaluation Notes
# [Describe how you evaluated your workflow here.]

# %%
# Add evaluation code here

# %% [markdown]
# # 11. Decision or Application Relevance
#
# This section is important. Explain how the project connects to disaster-management action.
#
# Useful prompts:
# - Who would use this output?
# - What decision could it support?
# - How does it improve awareness, response, or planning?
# - How could it fit into a larger workflow?

# %% [markdown]
# ## Practical Relevance
# [Write your discussion here.]

# %% [markdown]
# # 12. Limitations
#
# No project is perfect. Briefly describe the main limitations.
#
# Examples:
# - small dataset
# - synthetic examples
# - limited generalization
# - uncertain labels
# - no real-time integration
# - no field validation

# %% [markdown]
# ## Limitations
# [List and explain your main limitations here.]

# %% [markdown]
# # 13. Future Improvements
#
# Describe what you would improve next if the project continued.

# %% [markdown]
# ## Future Work
# [Write your future improvement ideas here.]

# %% [markdown]
# # 14. Final Reflection
#
# Summarize what you learned and what the project demonstrates.

# %% [markdown]
# ## Final Reflection
# [Write your reflection here.]
#
# Useful prompts:
# - What did this project demonstrate?
# - What was the biggest challenge?
# - What was the most useful lesson from the course?
# - How would you explain this project to a non-technical audience?

# %% [markdown]
# # 15. Optional Presentation-Ready Summary
#
# This section can help convert the notebook into a portfolio-ready artifact.

# %% [markdown]
# ## Executive Summary
# [Write a short 5–8 sentence summary here.]
#
# Suggested structure:
# - the problem
# - the data
# - the method
# - the main result
# - the practical value

# %% [markdown]
# # 16. Submission Checklist
#
# Use this checklist before submitting your project.

# %% [markdown]
# - [ ] Project title and student information completed
# - [ ] Problem statement clearly written
# - [ ] Data source explained
# - [ ] Workflow described clearly
# - [ ] Code runs from top to bottom
# - [ ] Results are shown with at least one table or figure
# - [ ] Evaluation section included
# - [ ] Practical relevance explained
# - [ ] Limitations and future work included
# - [ ] Notebook is clean and readable

# %% [markdown]
# # 17. Optional Grading Rubric Template
#
# This section can help students understand what a strong project looks like.

# %%
rubric_df = pd.DataFrame({
    "Category": [
        "Problem clarity",
        "Data understanding",
        "Workflow design",
        "Code quality",
        "Results and visualization",
        "Evaluation",
        "Practical relevance",
        "Reflection and communication"
    ],
    "What to demonstrate": [
        "Clear and meaningful problem definition",
        "Good explanation of inputs and assumptions",
        "Logical and reproducible process",
        "Readable, organized, and runnable notebook",
        "Clear outputs and useful interpretation",
        "Some evidence of performance or validation",
        "Strong connection to disaster-management value",
        "Clear writing and thoughtful reflection"
    ]
})

rubric_df
# Out:
#                        Category  \
# 0               Problem clarity
# 1            Data understanding
# 2               Workflow design
# 3                  Code quality
# 4     Results and visualization
# 5                    Evaluation
# 6           Practical relevance
# 7  Reflection and communication
#
#                               What to demonstrate
# 0         Clear and meaningful problem definition
# 1      Good explanation of inputs and assumptions
# 2                Logical and reproducible process
# 3      Readable, organized, and runnable notebook
# 4         Clear outputs and useful interpretation
# 5      Some evidence of performance or validation
# 6  Strong connection to disaster-management value
# 7         Clear writing and thoughtful reflection

# %% [markdown]
# ## Closing Note
#
# This final notebook should feel like a **small but complete project**, not just a collection of code cells.
#
# The strongest submissions will:
# - tell a clear story
# - connect technical work to practical value
# - present results cleanly
# - show thoughtful reflection on limitations and next steps
